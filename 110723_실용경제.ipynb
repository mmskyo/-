# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

# %%
#files.upload()

# %%
df = pd.read_csv("housing_dataset.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
sns.barplot(data = df.isnull().sum().reset_index(), y = "index", x = 0)
plt.show()

# %%
missing_val = df.isnull().sum()

# %%
sns.barplot(data = missing_val[missing_val > 0].reset_index(), y = "index", x = 0)
plt.show()

# %%
len(missing_val[missing_val>0]) #length
# Out:
# 19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
1460*81
# Out:
# 118260

# %%
df.size
# Out:
# 118260

# %%
df.shape
# Out:
# (1460, 81)

# %%
# total 변수명을 전체 데이터 갯수로 설정
total = df.size

# 각 칼럼 당 결측치 데이터 갯수
missing_col = df.isnull().sum()

# 데이터에서 결측치 합계
missing_total = missing_col.sum()

# %%
# 결측치가 전체 데이터에서 차지하는 비율
missing_total/total*100
# Out:
# 5.889565364451209

# %%
missing_total
# Out:
# 6965

# %%
missing_val = df.isnull().sum()

missing = missing_val[missing_val > 0]

# %%
missing
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
missing_val[missing_val == 0] #결측치가 하나도 없는 거
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 62, dtype: int64

# %%
missing.sort_values(inplace = True) #오름차순

# %%
missing
# Out:
# Electrical         1
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# BsmtExposure      38
# BsmtFinType2      38
# GarageCond        81
# GarageQual        81
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# LotFrontage      259
# FireplaceQu      690
# Fence           1179
# Alley           1369
# MiscFeature     1406
# PoolQC          1453
# dtype: int64

# %%
missing.plot.bar()
plt.title("Missing Values")
plt.xlabel("feature names")
plt.ylabel("count")
plt.show()

# %% [markdown]
# # 결측치를 다루는 방법
#
#  1. 삭제 : 행 또는 열의 missing value를 삭제
#
#  df.dropna()
#
#    - axis = 0 rows 삭제
#    - axis = 1 columns 삭제

# %% [markdown]
# - 여기에서 우리는 80% 이상의 결측치를 갖는 변수를 삭제하기로 함

# %%
col_list = ["Fence", "Alley", "MiscFeature", "PoolQC"]

# %%
df[col_list].isnull().sum() #잘 들어왔나 확인
# Out:
# Fence          1179
# Alley          1369
# MiscFeature    1406
# PoolQC         1453
# dtype: int64

# %%
df.drop(col_list, axis = 1, inplace = True)  #영구히 삭제

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %% [markdown]
# # imputing missing values
#
# ### replace method
#
#  - replace NaNs with zeros
#
#  - replace NaNs with each columns mean/median/mode
#
#  - sklearn simpleimputer() 자동적으로 알아서 바꿔줌
#
#  - knn으로 바꾸기
#
#  - 이전/이후 행의 값을 사용하는 방법 bfill/ffill (back/forward)
#
#  - interpolation method

# %% [markdown]
# ### 1. Replace method
#
#  - NaN을 df.replace() 메소드를 통해서 결측치를 바꾸는 방법
#
#  - 종종 데이터에는 NA, ___, ?, !?, @와 같은 특수문자또는 symbols 들이 포함되어 있음
#    - df.replace("?", np.nan) ?를 nan로 바꿈

# %%
missing
# Out:
# Electrical         1
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# BsmtExposure      38
# BsmtFinType2      38
# GarageCond        81
# GarageQual        81
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# LotFrontage      259
# FireplaceQu      690
# Fence           1179
# Alley           1369
# MiscFeature     1406
# PoolQC          1453
# dtype: int64

# %%
df["LotFrontage"].unique()
# Out:
# array([ 65.,  80.,  68.,  60.,  84.,  85.,  75.,  nan,  51.,  50.,  70.,
#         91.,  72.,  66., 101.,  57.,  44., 110.,  98.,  47., 108., 112.,
#         74., 115.,  61.,  48.,  33.,  52., 100.,  24.,  89.,  63.,  76.,
#         81.,  95.,  69.,  21.,  32.,  78., 121., 122.,  40., 105.,  73.,
#         77.,  64.,  94.,  34.,  90.,  55.,  88.,  82.,  71., 120., 107.,
#         92., 134.,  62.,  86., 141.,  97.,  54.,  41.,  79., 174.,  99.,
#         67.,  83.,  43., 103.,  93.,  30., 129., 140.,  35.,  37., 118.,
#         87., 116., 150., 111.,  49.,  96.,  59.,  36.,  56., 102.,  58.,
#         38., 109., 130.,  53., 137.,  45., 106., 104.,  42.,  39., 144.,
#        114., 128., 149., 313., 168., 182., 138., 160., 152., 124., 153.,
#         46.])

# %% [markdown]
# #2. 결측치를 0로 바꾸는 방법
#
#   - df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
df["MasVnrArea"] = df["MasVnrArea"].fillna(0)

#df.["MasVnrArea"] = df["MasVnrArea"].replace(np.nan, 0) 동일한 결과

# %%
df["MasVnrArea"].isnull().sum()
# Out:
# 0

# %%
df[["MasVnrArea"]]
# Out:
#       MasVnrArea
# 0          196.0
# 1            0.0
# 2          162.0
# 3            0.0
# 4          350.0
# ...          ...
# 1455         0.0
# 1456       119.0
# 1457         0.0
# 1458         0.0
# 1459         0.0
#
# [1460 rows x 1 columns]

# %% [markdown]
# # 3. NaNs를 mean/median으로 바꾸기
#
#  - 수치형 데이터로 이루어진 변수 또는 칼럼의 경우에, 결측치를  mean/median으로 채워넣을 수 있음
#
#  - pd.to_numeric() 메소드 사용

# %%
# outliar가 많으면 mean이 왜곡되니까 median<->mean

# %%
df["GarageYrBlt"]
# Out:
# 0       2003.0
# 1       1976.0
# 2       2001.0
# 3       1998.0
# 4       2000.0
#          ...
# 1455    1999.0
# 1456    1978.0
# 1457    1941.0
# 1458    1950.0
# 1459    1965.0
# Name: GarageYrBlt, Length: 1460, dtype: float64

# %%
df = pd.read_csv("housing_dataset.csv")

# %%
df["LotFrontage"].unique()
# Out:
# array([ 65.,  80.,  68.,  60.,  84.,  85.,  75.,  nan,  51.,  50.,  70.,
#         91.,  72.,  66., 101.,  57.,  44., 110.,  98.,  47., 108., 112.,
#         74., 115.,  61.,  48.,  33.,  52., 100.,  24.,  89.,  63.,  76.,
#         81.,  95.,  69.,  21.,  32.,  78., 121., 122.,  40., 105.,  73.,
#         77.,  64.,  94.,  34.,  90.,  55.,  88.,  82.,  71., 120., 107.,
#         92., 134.,  62.,  86., 141.,  97.,  54.,  41.,  79., 174.,  99.,
#         67.,  83.,  43., 103.,  93.,  30., 129., 140.,  35.,  37., 118.,
#         87., 116., 150., 111.,  49.,  96.,  59.,  36.,  56., 102.,  58.,
#         38., 109., 130.,  53., 137.,  45., 106., 104.,  42.,  39., 144.,
#        114., 128., 149., 313., 168., 182., 138., 160., 152., 124., 153.,
#         46.])

# %%
df["LotFrontage"] = df["LotFrontage"].fillna(df["LotFrontage"].mean())

# %% [markdown]
# - 다만, 이상치가 많은 경우에 결측치를 mean 대신 median 선택하는 것이 나음

# %%
df["LotFrontage"]
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %% [markdown]
# ## 4. 결측치를 mode로 채우기

# %%
df["GarageType"].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types'],
#       dtype=object)

# %%
df["GarageType"].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
df["GarageType"] = df["GarageType"].fillna(df["GarageType"].mode()[0])

# %%
df["GarageType"].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', 'Basment', '2Types'],
#       dtype=object)

# %%
df["GarageType"].value_counts()
# Out:
# Attchd     951
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %% [markdown]
# ## 5. Simple Imputer

# %%
df = pd.read_csv("housing_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df1 = df[["MasVnrArea"]].copy()

# %%
df1.head()
# Out:
#    MasVnrArea
# 0       196.0
# 1         0.0
# 2       162.0
# 3         0.0
# 4       350.0

# %%
df1.isnull().sum()
# Out:
# MasVnrArea    8
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
df1["MasVnrArea"] = df1["MasVnrArea"].isnull()

# %%
df1["MasVnrArea"].isnull()
imputer = SimpleImputer(strategy = "mean")
impute_data = imputer.fit_transform(df1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MasVnrArea  1460 non-null   bool
# dtypes: bool(1)
# memory usage: 1.6 KB

# %% [markdown]
# ## 6. KNN
#
# - K Nearest Neighbors:
#
# k = 3, k = 7 == hyper parameter 미리 정해져있음

# %% [markdown]
# ![knn.webp](data:image/webp;base64,...)

# %%
df2 = df[["MasVnrArea"]].copy() #대괄호 두개를 써야 시리즈가 아니라 딕셔너리로나옴

# %%
df2
# Out:
#       MasVnrArea
# 0          196.0
# 1            0.0
# 2          162.0
# 3            0.0
# 4          350.0
# ...          ...
# 1455         0.0
# 1456       119.0
# 1457         0.0
# 1458         0.0
# 1459         0.0
#
# [1460 rows x 1 columns]

# %%
df2["MasVnrArea"] = df2["MasVnrArea"].isnull()

# %%
df2["MasVnrArea"]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: MasVnrArea, Length: 1460, dtype: bool

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer(n_neighbors = 3)
imputer_data = imputer.fit_transform(df2)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MasVnrArea  1460 non-null   bool
# dtypes: bool(1)
# memory usage: 1.6 KB

# %% [markdown]
# ## ffill, bfill 활용하여 결측치 채우기
#
#  - forward value
#  - backward value

# %%
df["GarageType"].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types'],
#       dtype=object)

# %%
df["GarageType"] = df["GarageType"].fillna(method = "ffill")
#df["GarageType"] = df["GarageType"].fillna(method = "bfill")

# %%
df["GarageType"].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', 'Basment', '2Types'],
#       dtype=object)

# %% [markdown]
# ## 7. interpolation
#
# - interpolate() 메소드 사용
# - 시계열 유용

# %%
# df["column"].interpolate(method = "linear", direction = "forward") 선형으로 그려서 채우겠다.
